# %%
import pandas as pd
import numpy as np
import time
from openpyxl import load_workbook
import itertools

# Read input data
data = pd.read_excel('/Users/workk/Documents/[Think!]/[FMK]/Research Things/Economic Dispatch/[Economic Emission Dispatch (EED)]/Datasets/Jamali/EED8u.xlsx')
a = data['a'].values
b = data['b'].values
c = data['c'].values
d = data['d'].values
e = data['e'].values
f = data['f'].values
Minimum_Capacity = data['pmin'].values
Maximum_Capacity = data['pmax'].values
ramp_up = data['rampup'].values
ramp_down = data['rampdown'].values
Unit = data['Unit'].values

# Read power demand data
power_demand_data = pd.read_excel('/Users/workk/Documents/[Think!]/[FMK]/Research Things/Economic Dispatch/[Economic Emission Dispatch (EED)]/Datasets/Jamali/EED_demand8u.xlsx')
power_demand = power_demand_data['load3'].values

# Initialize an empty list to store results for each demand
all_outputs = []

# Define function to calculate fuel cost
def calculate_fuel_cost(P, a, b, c):
    squaredP = np.multiply(P, P)
    Fuel_Cost = np.divide(np.add(a, np.multiply(b, P) + np.multiply(c, squaredP)), 14385)
    return np.sum(Fuel_Cost)

# Define function to calculate emissions
def calculate_emissions(P, d, e, f):
    Emissions = np.divide(np.add(np.add(d, np.multiply(e, P)), np.multiply(f, np.power(P, 2))), 1e6)
    return np.sum(Emissions)

# Objective function: weighted sum of fuel cost and emissions
def objective_function(P, a, b, c, d, e, f, demand, penalty_factor, w1, w2):
    fuel_cost = calculate_fuel_cost(P, a, b, c)
    emissions = calculate_emissions(P, d, e, f)
    power_difference = np.sum(P) - demand
    penalty_term = penalty_factor * abs(power_difference)
    return w1 * fuel_cost + w2 * emissions + penalty_term

# Constraints: total power production must meet the demand
def power_balance_constraint(P, demand):
    return np.sum(P) - demand

# Boundary constraints for generation limits
bounds = [(Minimum_Capacity[i], Maximum_Capacity[i]) for i in range(len(Minimum_Capacity))]

# Backtracking line search function
def backtracking_line_search(P, grad, func, alpha=0.3, beta=0.8, tol=1e-6):
    step = 1.0
    while step > tol:
        new_P = P - step * grad
        if func(new_P) < func(P) - alpha * step * np.dot(grad, grad):
            return new_P
        step *= beta
    return P

# GRASP-based Hyper-heuristic with Backtracking Line Search
def grasp_heuristic(func, bounds, max_iterations=100, alpha=0.3, tol=1e-6):
    n = len(bounds)
    best_solution = None
    best_value = float('inf')

    for iteration in range(max_iterations):
        # Constructive Phase
        P = np.zeros(n)
        for i in range(n):
            candidates = np.linspace(bounds[i][0], bounds[i][1], 100)
            np.random.shuffle(candidates)
            candidates = candidates[:int(alpha * len(candidates))]
            best_candidate = None
            best_candidate_value = float('inf')
            for candidate in candidates:
                P[i] = candidate
                value = func(P)
                if value < best_candidate_value:
                    best_candidate_value = value
                    best_candidate = candidate
            P[i] = best_candidate

        # Local Search Phase with Backtracking Line Search
        step = 1.0
        while step > tol:
            grad = np.zeros(n)
            for i in range(n):
                delta = np.zeros(n)
                delta[i] = 1e-8
                grad[i] = (func(P + delta) - func(P - delta)) / (2 * 1e-8)
            new_P = backtracking_line_search(P, grad, func, alpha=0.3, beta=0.8, tol=1e-6)
            if np.allclose(new_P, P, atol=tol):
                break
            P = new_P
            step *= 0.5

        value = func(P)
        if value < best_value:
            best_value = value
            best_solution = P

    return best_solution

# Enforce ramp rate limits
def enforce_ramp_limits(previous_output, current_output, ramp_up, ramp_down, min_capacity, max_capacity):
    adjusted_output = np.copy(current_output)
    ramp_rate = current_output - previous_output

    # Apply ramp up/down constraints
    for i in range(len(adjusted_output)):
        if ramp_rate[i] > ramp_up[i]:
            adjusted_output[i] = previous_output[i] + ramp_up[i]  # Limit ramp up
        elif ramp_rate[i] < -ramp_down[i]:
            adjusted_output[i] = previous_output[i] - ramp_down[i]  # Limit ramp down

        # Ensure output respects generation limits
        adjusted_output[i] = max(min(adjusted_output[i], max_capacity[i]), min_capacity[i])

    return adjusted_output

# Apply unit commitment to determine which units should be on/off based on demand
def apply_unit_commitment(demand, pmin, pmax):
    if demand < np.sum(pmin):
        # Try different combinations of units to meet low demand
        for r in range(1, len(pmin) + 1):
            for subset in itertools.combinations(range(len(pmin)), r):
                active_units = np.zeros(len(pmin), dtype=int)
                active_units[list(subset)] = 1
                
                # Calculate generation range for this subset
                min_gen = np.sum(pmin[active_units == 1])
                max_gen = np.sum(pmax[active_units == 1])
                
                # Check if this subset can meet the demand
                if min_gen <= demand <= max_gen:
                    return active_units  # Return the selected subset as binary on/off indicators
    return np.ones(len(pmin), dtype=int)

# Optimization process for each demand
penalty_factor = 1e6
tol = 1e-3
scenarios = [(1, 0)]
all_scenario_results = []

for scenario_index, (w1, w2) in enumerate(scenarios, start=1):
    print(f"Running scenario {scenario_index}: w1={w1}, w2={w2}")
    all_outputs = []
    schedulling = []

    for load_counter, demand in enumerate(power_demand, start=1):
        start_time = time.time()

        # Determine unit commitment
        unit_commitment = apply_unit_commitment(demand, Minimum_Capacity, Maximum_Capacity)
        bounds = [(Minimum_Capacity[i] * unit_commitment[i], Maximum_Capacity[i] * unit_commitment[i]) for i in range(len(Minimum_Capacity))]

        # Initial guess for optimization
        P = np.random.uniform(low=Minimum_Capacity * unit_commitment, high=Maximum_Capacity * unit_commitment, size=len(Minimum_Capacity))

        def func_to_minimize(P):
            return objective_function(P, a, b, c, d, e, f, demand, penalty_factor, w1, w2)

        P = grasp_heuristic(func_to_minimize, bounds, tol=tol)
        P = np.minimum(np.maximum(P, Minimum_Capacity * unit_commitment), Maximum_Capacity * unit_commitment)

        # Force power balance if violated
        power_difference = np.sum(P) - demand
        while abs(power_difference) > tol:
            adjustment_per_unit = power_difference / len(P)
            P -= adjustment_per_unit
            # Ensure P stays within bounds
            P = np.minimum(np.maximum(P, Minimum_Capacity * unit_commitment), Maximum_Capacity * unit_commitment)
            power_difference = np.sum(P) - demand

        end_time = time.time()

        # Results extraction
        P_optimal = P
        fuel_cost = calculate_fuel_cost(P_optimal, a, b, c)
        emissions = calculate_emissions(P_optimal, d, e, f)

        # Output Results
        output = pd.DataFrame({'Unit': Unit, 'On/Off Status': unit_commitment, 'Power Produced (MW)': P_optimal, 'Emissions (Tons)': emissions})
        print("Load Counter: {}".format(load_counter))
        print(f"Output for Power Demand {demand:.2f} MW")
        print(output)
        print(f"Total Power Produced: {np.sum(P_optimal):.2f} MW")
        print(f'Total Fuel Cost: Rp {fuel_cost}')
        print('Total Emissions (Tons): ', emissions)
        print(f'Computation Time: {end_time - start_time} seconds')
        print('------------------------------------------------\n')

        all_outputs.append({'Demand': demand, 
                            'Output': output, 
                            'Total Power Produced': np.sum(P_optimal),
                            'Total Fuel Cost': fuel_cost,  
                            'Total Emissions (Tons)': emissions,
                            'Computation Time': end_time - start_time})

        # Scheduling
        output_info = {'Demand': power_demand[load_counter - 1]}
        for unit_index, unit in enumerate(Unit):
            output_info[f'Unit {unit} Power Produced'] = P_optimal[unit_index]
            output_info[f'Unit {unit} Cost'] = fuel_cost  
            output_info[f'Unit {unit} Emissions'] = emissions  

        schedulling.append(output_info)

    all_scenario_results.append((all_outputs, schedulling))

# Save results for all scenarios to Excel
output_file_path = '/Users/workk/Documents/[Think!]/[FMK]/Research Things/Economic Dispatch/Output/GRASP-BLS (EED-UC).xlsx'
with pd.ExcelWriter(output_file_path) as writer:
    for scenario_index, (all_outputs, schedulling) in enumerate(all_scenario_results, start=1):
        # Calculate ramp rates and generation limits for the current scenario
        ramp_rates = []
        generation_limits = []
        for i in range(1, len(power_demand)):  # Start from 1 because there's no previous output for the first demand
            previous_output = all_outputs[i-1]['Output']['Power Produced (MW)'].values
            current_output = all_outputs[i]['Output']['Power Produced (MW)'].values

            # Enforce ramp rate limits
            adjusted_output = enforce_ramp_limits(previous_output, current_output, ramp_up, ramp_down, Minimum_Capacity, Maximum_Capacity)

            ramp_rate = adjusted_output - previous_output

            # Check for ramp rate violations
            violations = np.logical_or(ramp_rate > ramp_up, ramp_rate < -ramp_down)
            ramp_rate_info = {'Demand': power_demand[i]}
            generation_limit_info = {'Demand': power_demand[i]}
            for unit_index, unit in enumerate(Unit):
                ramp_rate_info[f'Unit {unit}'] = ramp_rate[unit_index]
                ramp_rate_info[f'Unit {unit} Violation'] = violations[unit_index]

                # Check for generation limit violations after adjusting output
                gen_violation = (adjusted_output[unit_index] < Minimum_Capacity[unit_index]) or (adjusted_output[unit_index] > Maximum_Capacity[unit_index])
                generation_limit_info[f'Unit {unit}'] = adjusted_output[unit_index]
                generation_limit_info[f'Unit {unit} Violation'] = gen_violation

            ramp_rates.append(ramp_rate_info)
            generation_limits.append(generation_limit_info)

            # Update the optimal power output to reflect ramp rate adjustments
            all_outputs[i]['Output']['Power Produced (MW)'] = adjusted_output

        # Write DataFrames only if they are not empty
        if schedulling:
            pd.DataFrame(schedulling).to_excel(writer, sheet_name=f'Scenario {scenario_index} Schedulling', index=False)
        if all_outputs:
            pd.DataFrame(all_outputs).to_excel(writer, sheet_name=f'Scenario {scenario_index} Summary', index=False)
        if ramp_rates:
            pd.DataFrame(ramp_rates).to_excel(writer, sheet_name=f'Scenario {scenario_index} Ramp Rates', index=False)
        if generation_limits:
            pd.DataFrame(generation_limits).to_excel(writer, sheet_name=f'Scenario {scenario_index} Generation Limits', index=False)

print("All results saved to 'GRASP-BLS (EED-UC).xlsx'")
# Out:
# Running scenario 1: w1=1, w2=0
# Load Counter: 1
# Output for Power Demand 5485.70 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4121.486748       4823.409573
# 1     2              1          1364.214021       4823.409573
# 2     3              0             0.000000       4823.409573
# 3     4              0             0.000000       4823.409573
# 4     5              0             0.000000       4823.409573
# 5     6              0             0.000000       4823.409573
# 6     7              0             0.000000       4823.409573
# 7     8              0             0.000000       4823.409573
# Total Power Produced: 5485.70 MW
# Total Fuel Cost: Rp 940405.2057881497
# Total Emissions (Tons):  4823.409572797383
# Computation Time: 0.4716207981109619 seconds
# ------------------------------------------------
#
# Load Counter: 2
# Output for Power Demand 5352.10 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4043.201108        4805.15131
# 1     2              1          1308.898078        4805.15131
# 2     3              0             0.000000        4805.15131
# 3     4              0             0.000000        4805.15131
# 4     5              0             0.000000        4805.15131
# 5     6              0             0.000000        4805.15131
# 6     7              0             0.000000        4805.15131
# 7     8              0             0.000000        4805.15131
# Total Power Produced: 5352.10 MW
# Total Fuel Cost: Rp 921220.8403304971
# Total Emissions (Tons):  4805.151309530945
# Computation Time: 0.5337307453155518 seconds
# ------------------------------------------------
#
# Load Counter: 3
# Output for Power Demand 5200.30 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4016.675713       4773.043408
# 1     2              1          1183.625208       4773.043408
# 2     3              0             0.000000       4773.043408
# 3     4              0             0.000000       4773.043408
# 4     5              0             0.000000       4773.043408
# 5     6              0             0.000000       4773.043408
# 6     7              0             0.000000       4773.043408
# 7     8              0             0.000000       4773.043408
# Total Power Produced: 5200.30 MW
# Total Fuel Cost: Rp 879485.1785421846
# Total Emissions (Tons):  4773.043407602612
# Computation Time: 0.5462520122528076 seconds
# ------------------------------------------------
#
# Load Counter: 4
# Output for Power Demand 5124.80 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4121.461016        4741.06363
# 1     2              1          1003.339804        4741.06363
# 2     3              0             0.000000        4741.06363
# 3     4              0             0.000000        4741.06363
# 4     5              0             0.000000        4741.06363
# 5     6              0             0.000000        4741.06363
# 6     7              0             0.000000        4741.06363
# 7     8              0             0.000000        4741.06363
# Total Power Produced: 5124.80 MW
# Total Fuel Cost: Rp 822921.5135647587
# Total Emissions (Tons):  4741.063630419443
# Computation Time: 0.6289730072021484 seconds
# ------------------------------------------------
#
# Load Counter: 5
# Output for Power Demand 5287.60 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4173.507514       4764.731803
# 1     2              1          1114.093373       4764.731803
# 2     3              0             0.000000       4764.731803
# 3     4              0             0.000000       4764.731803
# 4     5              0             0.000000       4764.731803
# 5     6              0             0.000000       4764.731803
# 6     7              0             0.000000       4764.731803
# 7     8              0             0.000000       4764.731803
# Total Power Produced: 5287.60 MW
# Total Fuel Cost: Rp 857700.5393026567
# Total Emissions (Tons):  4764.731802923393
# Computation Time: 0.5249099731445312 seconds
# ------------------------------------------------
#
# Load Counter: 6
# Output for Power Demand 5548.30 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4198.968619       4820.630693
# 1     2              1          1349.332255       4820.630693
# 2     3              0             0.000000       4820.630693
# 3     4              0             0.000000       4820.630693
# 4     5              0             0.000000       4820.630693
# 5     6              0             0.000000       4820.630693
# 6     7              0             0.000000       4820.630693
# 7     8              0             0.000000       4820.630693
# Total Power Produced: 5548.30 MW
# Total Fuel Cost: Rp 935337.9081719802
# Total Emissions (Tons):  4820.630692644627
# Computation Time: 0.5183079242706299 seconds
# ------------------------------------------------
#
# Load Counter: 7
# Output for Power Demand 6314.20 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          2175.200969       8452.584398
# 1     2              1           934.000000       8452.584398
# 2     3              1           404.000000       8452.584398
# 3     4              1           208.000000       8452.584398
# 4     5              1           848.000000       8452.584398
# 5     6              1          1080.000000       8452.584398
# 6     7              1           360.000000       8452.584398
# 7     8              1           305.000000       8452.584398
# Total Power Produced: 6314.20 MW
# Total Fuel Cost: Rp 1219755.2595970673
# Total Emissions (Tons):  8452.584397787301
# Computation Time: 1.1081557273864746 seconds
# ------------------------------------------------
#
# Load Counter: 8
# Output for Power Demand 7837.40 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          3183.882221       9292.250159
# 1     2              1          1448.518681       9292.250159
# 2     3              1           404.000000       9292.250159
# 3     4              1           208.000000       9292.250159
# 4     5              1           848.000000       9292.250159
# 5     6              1          1080.000000       9292.250159
# 6     7              1           360.000000       9292.250159
# 7     8              1           305.000000       9292.250159
# Total Power Produced: 7837.40 MW
# Total Fuel Cost: Rp 1471012.51202263
# Total Emissions (Tons):  9292.250159063584
# Computation Time: 1.0989961624145508 seconds
# ------------------------------------------------
#
# Load Counter: 9
# Output for Power Demand 9456.70 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          3790.547212       10003.42248
# 1     2              1          1909.016413       10003.42248
# 2     3              1           644.744223       10003.42248
# 3     4              1           327.936143       10003.42248
# 4     5              1          1039.456677       10003.42248
# 5     6              1          1080.000000       10003.42248
# 6     7              1           360.000000       10003.42248
# 7     8              1           305.000000       10003.42248
# Total Power Produced: 9456.70 MW
# Total Fuel Cost: Rp 1701375.2249233269
# Total Emissions (Tons):  10003.422480254267
# Computation Time: 1.0894510746002197 seconds
# ------------------------------------------------
#
# Load Counter: 10
# Output for Power Demand 11762.50 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4084.314589      12385.196371
# 1     2              1          2178.361925      12385.196371
# 2     3              1           886.213927      12385.196371
# 3     4              1           584.314937      12385.196371
# 4     5              1          2284.295181      12385.196371
# 5     6              1          1080.000000      12385.196371
# 6     7              1           360.000000      12385.196371
# 7     8              1           305.000000      12385.196371
# Total Power Produced: 11762.50 MW
# Total Fuel Cost: Rp 2036812.95671955
# Total Emissions (Tons):  12385.1963714837
# Computation Time: 0.9657578468322754 seconds
# ------------------------------------------------
#
# Load Counter: 11
# Output for Power Demand 13345.80 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4103.985826      15512.782886
# 1     2              1          2142.518407      15512.782886
# 2     3              1           905.884417      15512.782886
# 3     4              1           599.015730      15512.782886
# 4     5              1          2256.925322      15512.782886
# 5     6              1          2672.470730      15512.782886
# 6     7              1           360.000000      15512.782886
# 7     8              1           305.000000      15512.782886
# Total Power Produced: 13345.80 MW
# Total Fuel Cost: Rp 2340721.366741197
# Total Emissions (Tons):  15512.782885800232
# Computation Time: 0.9754927158355713 seconds
# ------------------------------------------------
#
# Load Counter: 12
# Output for Power Demand 14278.90 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4070.032017       17847.97495
# 1     2              1          2176.370351       17847.97495
# 2     3              1           885.892418       17847.97495
# 3     4              1           566.377267       17847.97495
# 4     5              1          2296.166013       17847.97495
# 5     6              1          3619.062333       17847.97495
# 6     7              1           360.000000       17847.97495
# 7     8              1           305.000000       17847.97495
# Total Power Produced: 14278.90 MW
# Total Fuel Cost: Rp 2590233.4028381556
# Total Emissions (Tons):  17847.974950267577
# Computation Time: 0.9669721126556396 seconds
# ------------------------------------------------
#
# Load Counter: 13
# Output for Power Demand 14913.20 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4071.444319      19445.403622
# 1     2              1          2205.529668      19445.403622
# 2     3              1           862.903288      19445.403622
# 3     4              1           597.610358      19445.403622
# 4     5              1          2266.224465      19445.403622
# 5     6              1          4244.488493      19445.403622
# 6     7              1           360.000000      19445.403622
# 7     8              1           305.000000      19445.403622
# Total Power Produced: 14913.20 MW
# Total Fuel Cost: Rp 2763465.3211340723
# Total Emissions (Tons):  19445.403621607053
# Computation Time: 0.9740722179412842 seconds
# ------------------------------------------------
#
# Load Counter: 14
# Output for Power Demand 15312.80 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4110.882084      20337.550589
# 1     2              1          2204.919688      20337.550589
# 2     3              1           900.567735      20337.550589
# 3     4              1           610.870765      20337.550589
# 4     5              1          2232.452917      20337.550589
# 5     6              1          4588.107072      20337.550589
# 6     7              1           360.000000      20337.550589
# 7     8              1           305.000000      20337.550589
# Total Power Produced: 15312.80 MW
# Total Fuel Cost: Rp 2853846.7240724238
# Total Emissions (Tons):  20337.550588552083
# Computation Time: 0.964353084564209 seconds
# ------------------------------------------------
#
# Load Counter: 15
# Output for Power Demand 15739.60 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4157.005025      21062.298221
# 1     2              1          2223.329843      21062.298221
# 2     3              1           928.397989      21062.298221
# 3     4              1           632.155548      21062.298221
# 4     5              1          2356.994471      21062.298221
# 5     6              1          4634.276758      21062.298221
# 6     7              1           502.441111      21062.298221
# 7     8              1           305.000000      21062.298221
# Total Power Produced: 15739.60 MW
# Total Fuel Cost: Rp 2923205.2639624067
# Total Emissions (Tons):  21062.298220846846
# Computation Time: 0.897845983505249 seconds
# ------------------------------------------------
#
# Load Counter: 16
# Output for Power Demand 16104.30 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4200.000000      21408.090593
# 1     2              1          2169.288149      21408.090593
# 2     3              1          1001.975018      21408.090593
# 3     4              1           675.227543      21408.090593
# 4     5              1          2368.722492      21408.090593
# 5     6              1          4310.298250      21408.090593
# 6     7              1           889.166937      21408.090593
# 7     8              1           489.621482      21408.090593
# Total Power Produced: 16104.30 MW
# Total Fuel Cost: Rp 2961732.496137137
# Total Emissions (Tons):  21408.090592701075
# Computation Time: 0.8570098876953125 seconds
# ------------------------------------------------
#
# Load Counter: 17
# Output for Power Demand 16527.90 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4199.996338      22254.272316
# 1     2              1          2280.238763      22254.272316
# 2     3              1           995.794318      22254.272316
# 3     4              1           695.026641      22254.272316
# 4     5              1          2321.612500      22254.272316
# 5     6              1          4603.875126      22254.272316
# 6     7              1           889.087247      22254.272316
# 7     8              1           542.269066      22254.272316
# Total Power Produced: 16527.90 MW
# Total Fuel Cost: Rp 3104746.480577306
# Total Emissions (Tons):  22254.272315967013
# Computation Time: 0.5426287651062012 seconds
# ------------------------------------------------
#
# Load Counter: 18
# Output for Power Demand 17053.40 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4173.806313      23095.940502
# 1     2              1          2294.089141      23095.940502
# 2     3              1           983.563889      23095.940502
# 3     4              1           694.998232      23095.940502
# 4     5              1          2384.291162      23095.940502
# 5     6              1          4677.260859      23095.940502
# 6     7              1           894.513384      23095.940502
# 7     8              1           950.877020      23095.940502
# Total Power Produced: 17053.40 MW
# Total Fuel Cost: Rp 3307440.440424027
# Total Emissions (Tons):  23095.94050159121
# Computation Time: 0.4917929172515869 seconds
# ------------------------------------------------
#
# Load Counter: 19
# Output for Power Demand 17594.10 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4147.775829      23792.369492
# 1     2              1          2280.341486      23792.369492
# 2     3              1          1001.998051      23792.369492
# 3     4              1           695.129364      23792.369492
# 4     5              1          2400.000000      23792.369492
# 5     6              1          4677.391991      23792.369492
# 6     7              1           900.000000      23792.369492
# 7     8              1          1491.462698      23792.369492
# Total Power Produced: 17594.10 MW
# Total Fuel Cost: Rp 3519484.141111671
# Total Emissions (Tons):  23792.369492252874
# Computation Time: 0.5808708667755127 seconds
# ------------------------------------------------
#
# Load Counter: 20
# Output for Power Demand 17832.60 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4192.599039      24052.883205
# 1     2              1          2308.000000      24052.883205
# 2     3              1          1008.000000      24052.883205
# 3     4              1           700.000000      24052.883205
# 4     5              1          2400.000000      24052.883205
# 5     6              1          4714.000000      24052.883205
# 6     7              1           900.000000      24052.883205
# 7     8              1          1610.000000      24052.883205
# Total Power Produced: 17832.60 MW
# Total Fuel Cost: Rp 3588559.913107833
# Total Emissions (Tons):  24052.8832048606
# Computation Time: 0.8697831630706787 seconds
# ------------------------------------------------
#
# Load Counter: 21
# Output for Power Demand 17346.20 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4121.602272      23366.486202
# 1     2              1          2308.000000      23366.486202
# 2     3              1           965.380050      23366.486202
# 3     4              1           690.147726      23366.486202
# 4     5              1          2400.000000      23366.486202
# 5     6              1          4567.258837      23366.486202
# 6     7              1           894.632575      23366.486202
# 7     8              1          1399.178029      23366.486202
# Total Power Produced: 17346.20 MW
# Total Fuel Cost: Rp 3462412.649209895
# Total Emissions (Tons):  23366.486202095144
# Computation Time: 0.5138769149780273 seconds
# ------------------------------------------------
#
# Load Counter: 22
# Output for Power Demand 16034.70 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4081.227856      21845.561161
# 1     2              1          2253.800537      21845.561161
# 2     3              1           961.614148      21845.561161
# 3     4              1           659.715159      21845.561161
# 4     5              1          2296.989205      21845.561161
# 5     6              1          4636.979984      21845.561161
# 6     7              1           826.967239      21845.561161
# 7     8              1           317.405873      21845.561161
# Total Power Produced: 16034.70 MW
# Total Fuel Cost: Rp 2995099.5704101464
# Total Emissions (Tons):  21845.561161466638
# Computation Time: 0.8976399898529053 seconds
# ------------------------------------------------
#
# Load Counter: 23
# Output for Power Demand 12547.10 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4089.073726      13957.294623
# 1     2              1          2169.251649      13957.294623
# 2     3              1           872.671126      13957.294623
# 3     4              1           554.287287      13957.294623
# 4     5              1          2273.381057      13957.294623
# 5     6              1          1923.435715      13957.294623
# 6     7              1           360.000000      13957.294623
# 7     8              1           305.000000      13957.294623
# Total Power Produced: 12547.10 MW
# Total Fuel Cost: Rp 2192921.7776990393
# Total Emissions (Tons):  13957.294622937876
# Computation Time: 0.9628808498382568 seconds
# ------------------------------------------------
#
# Load Counter: 24
# Output for Power Demand 8974.50 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          3662.938786       9602.901812
# 1     2              1          1875.385880       9602.901812
# 2     3              1           575.588037       9602.901812
# 3     4              1           267.588037       9602.901812
# 4     5              1           848.000000       9602.901812
# 5     6              1          1080.000000       9602.901812
# 6     7              1           360.000000       9602.901812
# 7     8              1           305.000000       9602.901812
# Total Power Produced: 8974.50 MW
# Total Fuel Cost: Rp 1649381.7484576849
# Total Emissions (Tons):  9602.901812082828
# Computation Time: 1.098525047302246 seconds
# ------------------------------------------------
#
# All results saved to 'GRASP-BLS (EED-UC).xlsx'

# %%
import pandas as pd
import numpy as np
import time
from openpyxl import load_workbook
import itertools

# Read input data
data = pd.read_excel('/Users/workk/Documents/[Think!]/[FMK]/Research Things/Economic Dispatch/[Economic Emission Dispatch (EED)]/Datasets/Jamali/EED8u.xlsx')
a = data['a'].values
b = data['b'].values
c = data['c'].values
d = data['d'].values
e = data['e'].values
f = data['f'].values
Minimum_Capacity = data['pmin'].values
Maximum_Capacity = data['pmax'].values
ramp_up = data['rampup'].values
ramp_down = data['rampdown'].values
Unit = data['Unit'].values

# Read power demand data
power_demand_data = pd.read_excel('/Users/workk/Documents/[Think!]/[FMK]/Research Things/Economic Dispatch/[Economic Emission Dispatch (EED)]/Datasets/Jamali/EED_demand8u.xlsx')
power_demand = power_demand_data['load2'].values

# Initialize an empty list to store results for each demand
all_outputs = []

# Define function to calculate fuel cost
def calculate_fuel_cost(P, a, b, c):
    squaredP = np.multiply(P, P)
    Fuel_Cost = np.divide(np.add(a, np.multiply(b, P) + np.multiply(c, squaredP)), 14385)
    return np.sum(Fuel_Cost)

# Define function to calculate emissions
def calculate_emissions(P, d, e, f):
    Emissions = np.divide(np.add(np.add(d, np.multiply(e, P)), np.multiply(f, np.power(P, 2))), 1e6)
    return np.sum(Emissions)

# Objective function: weighted sum of fuel cost and emissions
def objective_function(P, a, b, c, d, e, f, demand, penalty_factor, w1, w2):
    fuel_cost = calculate_fuel_cost(P, a, b, c)
    emissions = calculate_emissions(P, d, e, f)
    power_difference = np.sum(P) - demand
    penalty_term = penalty_factor * abs(power_difference)
    return w1 * fuel_cost + w2 * emissions + penalty_term

# Constraints: total power production must meet the demand
def power_balance_constraint(P, demand):
    return np.sum(P) - demand

# Boundary constraints for generation limits
bounds = [(Minimum_Capacity[i], Maximum_Capacity[i]) for i in range(len(Minimum_Capacity))]

# Backtracking line search function
def backtracking_line_search(P, grad, func, alpha=0.3, beta=0.8, tol=1e-6):
    step = 1.0
    while step > tol:
        new_P = P - step * grad
        if func(new_P) < func(P) - alpha * step * np.dot(grad, grad):
            return new_P
        step *= beta
    return P

# GRASP-based Hyper-heuristic with Backtracking Line Search
def grasp_heuristic(func, bounds, max_iterations=100, alpha=0.3, tol=1e-6):
    n = len(bounds)
    best_solution = None
    best_value = float('inf')

    for iteration in range(max_iterations):
        # Constructive Phase
        P = np.zeros(n)
        for i in range(n):
            candidates = np.linspace(bounds[i][0], bounds[i][1], 100)
            np.random.shuffle(candidates)
            candidates = candidates[:int(alpha * len(candidates))]
            best_candidate = None
            best_candidate_value = float('inf')
            for candidate in candidates:
                P[i] = candidate
                value = func(P)
                if value < best_candidate_value:
                    best_candidate_value = value
                    best_candidate = candidate
            P[i] = best_candidate

        # Local Search Phase with Backtracking Line Search
        step = 1.0
        while step > tol:
            grad = np.zeros(n)
            for i in range(n):
                delta = np.zeros(n)
                delta[i] = 1e-8
                grad[i] = (func(P + delta) - func(P - delta)) / (2 * 1e-8)
            new_P = backtracking_line_search(P, grad, func, alpha=0.3, beta=0.8, tol=1e-6)
            if np.allclose(new_P, P, atol=tol):
                break
            P = new_P
            step *= 0.5

        value = func(P)
        if value < best_value:
            best_value = value
            best_solution = P

    return best_solution

# Enforce ramp rate limits
def enforce_ramp_limits(previous_output, current_output, ramp_up, ramp_down, min_capacity, max_capacity):
    adjusted_output = np.copy(current_output)
    ramp_rate = current_output - previous_output

    # Apply ramp up/down constraints
    for i in range(len(adjusted_output)):
        if ramp_rate[i] > ramp_up[i]:
            adjusted_output[i] = previous_output[i] + ramp_up[i]  # Limit ramp up
        elif ramp_rate[i] < -ramp_down[i]:
            adjusted_output[i] = previous_output[i] - ramp_down[i]  # Limit ramp down

        # Ensure output respects generation limits
        adjusted_output[i] = max(min(adjusted_output[i], max_capacity[i]), min_capacity[i])

    return adjusted_output

# Apply unit commitment to determine which units should be on/off based on demand
def apply_unit_commitment(demand, pmin, pmax):
    if demand < np.sum(pmin):
        # Try different combinations of units to meet low demand
        for r in range(1, len(pmin) + 1):
            for subset in itertools.combinations(range(len(pmin)), r):
                active_units = np.zeros(len(pmin), dtype=int)
                active_units[list(subset)] = 1
                
                # Calculate generation range for this subset
                min_gen = np.sum(pmin[active_units == 1])
                max_gen = np.sum(pmax[active_units == 1])
                
                # Check if this subset can meet the demand
                if min_gen <= demand <= max_gen:
                    return active_units  # Return the selected subset as binary on/off indicators
    return np.ones(len(pmin), dtype=int)

# Optimization process for each demand
penalty_factor = 1e6
tol = 1e-3
scenarios = [(1, 0)]
all_scenario_results = []

for scenario_index, (w1, w2) in enumerate(scenarios, start=1):
    print(f"Running scenario {scenario_index}: w1={w1}, w2={w2}")
    all_outputs = []
    schedulling = []

    for load_counter, demand in enumerate(power_demand, start=1):
        start_time = time.time()

        # Determine unit commitment
        unit_commitment = apply_unit_commitment(demand, Minimum_Capacity, Maximum_Capacity)
        bounds = [(Minimum_Capacity[i] * unit_commitment[i], Maximum_Capacity[i] * unit_commitment[i]) for i in range(len(Minimum_Capacity))]

        # Initial guess for optimization
        P = np.random.uniform(low=Minimum_Capacity * unit_commitment, high=Maximum_Capacity * unit_commitment, size=len(Minimum_Capacity))

        def func_to_minimize(P):
            return objective_function(P, a, b, c, d, e, f, demand, penalty_factor, w1, w2)

        P = grasp_heuristic(func_to_minimize, bounds, tol=tol)
        P = np.minimum(np.maximum(P, Minimum_Capacity * unit_commitment), Maximum_Capacity * unit_commitment)

        # Force power balance if violated
        power_difference = np.sum(P) - demand
        while abs(power_difference) > tol:
            adjustment_per_unit = power_difference / len(P)
            P -= adjustment_per_unit
            # Ensure P stays within bounds
            P = np.minimum(np.maximum(P, Minimum_Capacity * unit_commitment), Maximum_Capacity * unit_commitment)
            power_difference = np.sum(P) - demand

        end_time = time.time()

        # Results extraction
        P_optimal = P
        fuel_cost = calculate_fuel_cost(P_optimal, a, b, c)
        emissions = calculate_emissions(P_optimal, d, e, f)

        # Output Results
        output = pd.DataFrame({'Unit': Unit, 'On/Off Status': unit_commitment, 'Power Produced (MW)': P_optimal, 'Emissions (Tons)': emissions})
        print("Load Counter: {}".format(load_counter))
        print(f"Output for Power Demand {demand:.2f} MW")
        print(output)
        print(f"Total Power Produced: {np.sum(P_optimal):.2f} MW")
        print(f'Total Fuel Cost: Rp {fuel_cost}')
        print('Total Emissions (Tons): ', emissions)
        print(f'Computation Time: {end_time - start_time} seconds')
        print('------------------------------------------------\n')

        all_outputs.append({'Demand': demand, 
                            'Output': output, 
                            'Total Power Produced': np.sum(P_optimal),
                            'Total Fuel Cost': fuel_cost,  
                            'Total Emissions (Tons)': emissions,
                            'Computation Time': end_time - start_time})

        # Scheduling
        output_info = {'Demand': power_demand[load_counter - 1]}
        for unit_index, unit in enumerate(Unit):
            output_info[f'Unit {unit} Power Produced'] = P_optimal[unit_index]
            output_info[f'Unit {unit} Cost'] = fuel_cost  
            output_info[f'Unit {unit} Emissions'] = emissions  

        schedulling.append(output_info)

    all_scenario_results.append((all_outputs, schedulling))

# Save results for all scenarios to Excel
output_file_path = '/Users/workk/Documents/[Think!]/[FMK]/Research Things/Economic Dispatch/Output/GRASP-BLS (EED).xlsx'
with pd.ExcelWriter(output_file_path) as writer:
    for scenario_index, (all_outputs, schedulling) in enumerate(all_scenario_results, start=1):
        # Calculate ramp rates and generation limits for the current scenario
        ramp_rates = []
        generation_limits = []
        for i in range(1, len(power_demand)):  # Start from 1 because there's no previous output for the first demand
            previous_output = all_outputs[i-1]['Output']['Power Produced (MW)'].values
            current_output = all_outputs[i]['Output']['Power Produced (MW)'].values

            # Enforce ramp rate limits
            adjusted_output = enforce_ramp_limits(previous_output, current_output, ramp_up, ramp_down, Minimum_Capacity, Maximum_Capacity)

            ramp_rate = adjusted_output - previous_output

            # Check for ramp rate violations
            violations = np.logical_or(ramp_rate > ramp_up, ramp_rate < -ramp_down)
            ramp_rate_info = {'Demand': power_demand[i]}
            generation_limit_info = {'Demand': power_demand[i]}
            for unit_index, unit in enumerate(Unit):
                ramp_rate_info[f'Unit {unit}'] = ramp_rate[unit_index]
                ramp_rate_info[f'Unit {unit} Violation'] = violations[unit_index]

                # Check for generation limit violations after adjusting output
                gen_violation = (adjusted_output[unit_index] < Minimum_Capacity[unit_index]) or (adjusted_output[unit_index] > Maximum_Capacity[unit_index])
                generation_limit_info[f'Unit {unit}'] = adjusted_output[unit_index]
                generation_limit_info[f'Unit {unit} Violation'] = gen_violation

            ramp_rates.append(ramp_rate_info)
            generation_limits.append(generation_limit_info)

            # Update the optimal power output to reflect ramp rate adjustments
            all_outputs[i]['Output']['Power Produced (MW)'] = adjusted_output

        # Write DataFrames only if they are not empty
        if schedulling:
            pd.DataFrame(schedulling).to_excel(writer, sheet_name=f'Scenario {scenario_index} Schedulling', index=False)
        if all_outputs:
            pd.DataFrame(all_outputs).to_excel(writer, sheet_name=f'Scenario {scenario_index} Summary', index=False)
        if ramp_rates:
            pd.DataFrame(ramp_rates).to_excel(writer, sheet_name=f'Scenario {scenario_index} Ramp Rates', index=False)
        if generation_limits:
            pd.DataFrame(generation_limits).to_excel(writer, sheet_name=f'Scenario {scenario_index} Generation Limits', index=False)

print("All results saved to 'GRASP-BLS (EED).xlsx'")
# Out:
# Running scenario 1: w1=1, w2=0
# Load Counter: 1
# Output for Power Demand 6432.50 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          2293.500947       8562.137803
# 1     2              1           934.000000       8562.137803
# 2     3              1           404.000000       8562.137803
# 3     4              1           208.000000       8562.137803
# 4     5              1           848.000000       8562.137803
# 5     6              1          1080.000000       8562.137803
# 6     7              1           360.000000       8562.137803
# 7     8              1           305.000000       8562.137803
# Total Power Produced: 6432.50 MW
# Total Fuel Cost: Rp 1232463.6726381865
# Total Emissions (Tons):  8562.137802650894
# Computation Time: 1.0660459995269775 seconds
# ------------------------------------------------
#
# Load Counter: 2
# Output for Power Demand 6127.80 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1            1988.8009        8266.52228
# 1     2              1             934.0000        8266.52228
# 2     3              1             404.0000        8266.52228
# 3     4              1             208.0000        8266.52228
# 4     5              1             848.0000        8266.52228
# 5     6              1            1080.0000        8266.52228
# 6     7              1             360.0000        8266.52228
# 7     8              1             305.0000        8266.52228
# Total Power Produced: 6127.80 MW
# Total Fuel Cost: Rp 1198151.8575872274
# Total Emissions (Tons):  8266.522279638577
# Computation Time: 1.1324701309204102 seconds
# ------------------------------------------------
#
# Load Counter: 3
# Output for Power Demand 5893.40 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          1754.400887        8009.20021
# 1     2              1           934.000000        8009.20021
# 2     3              1           404.000000        8009.20021
# 3     4              1           208.000000        8009.20021
# 4     5              1           848.000000        8009.20021
# 5     6              1          1080.000000        8009.20021
# 6     7              1           360.000000        8009.20021
# 7     8              1           305.000000        8009.20021
# Total Power Produced: 5893.40 MW
# Total Fuel Cost: Rp 1168242.6230924039
# Total Emissions (Tons):  8009.200210194242
# Computation Time: 1.0389697551727295 seconds
# ------------------------------------------------
#
# Load Counter: 4
# Output for Power Demand 5769.60 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          1630.600994       7862.797397
# 1     2              1           934.000000       7862.797397
# 2     3              1           404.000000       7862.797397
# 3     4              1           208.000000       7862.797397
# 4     5              1           848.000000       7862.797397
# 5     6              1          1080.000000       7862.797397
# 6     7              1           360.000000       7862.797397
# 7     8              1           305.000000       7862.797397
# Total Power Produced: 5769.60 MW
# Total Fuel Cost: Rp 1151212.7731762982
# Total Emissions (Tons):  7862.797397154041
# Computation Time: 1.1152808666229248 seconds
# ------------------------------------------------
#
# Load Counter: 5
# Output for Power Demand 5823.90 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          1684.900983       7927.904543
# 1     2              1           934.000000       7927.904543
# 2     3              1           404.000000       7927.904543
# 3     4              1           208.000000       7927.904543
# 4     5              1           848.000000       7927.904543
# 5     6              1          1080.000000       7927.904543
# 6     7              1           360.000000       7927.904543
# 7     8              1           305.000000       7927.904543
# Total Power Produced: 5823.90 MW
# Total Fuel Cost: Rp 1158787.1901963435
# Total Emissions (Tons):  7927.904543448426
# Computation Time: 1.0744788646697998 seconds
# ------------------------------------------------
#
# Load Counter: 6
# Output for Power Demand 6187.30 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1           2048.30095        8327.70167
# 1     2              1            934.00000        8327.70167
# 2     3              1            404.00000        8327.70167
# 3     4              1            208.00000        8327.70167
# 4     5              1            848.00000        8327.70167
# 5     6              1           1080.00000        8327.70167
# 6     7              1            360.00000        8327.70167
# 7     8              1            305.00000        8327.70167
# Total Power Produced: 6187.30 MW
# Total Fuel Cost: Rp 1205257.7529572418
# Total Emissions (Tons):  8327.70167049788
# Computation Time: 1.1278808116912842 seconds
# ------------------------------------------------
#
# Load Counter: 7
# Output for Power Demand 7054.20 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          2865.432972       9007.545368
# 1     2              1           983.767802       9007.545368
# 2     3              1           404.000000       9007.545368
# 3     4              1           208.000000       9007.545368
# 4     5              1           848.000000       9007.545368
# 5     6              1          1080.000000       9007.545368
# 6     7              1           360.000000       9007.545368
# 7     8              1           305.000000       9007.545368
# Total Power Produced: 7054.20 MW
# Total Fuel Cost: Rp 1298053.269767238
# Total Emissions (Tons):  9007.545367547627
# Computation Time: 1.0739562511444092 seconds
# ------------------------------------------------
#
# Load Counter: 8
# Output for Power Demand 8429.70 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          3532.316264       9503.350368
# 1     2              1          1692.384708       9503.350368
# 2     3              1           404.000000       9503.350368
# 3     4              1           208.000000       9503.350368
# 4     5              1           848.000000       9503.350368
# 5     6              1          1080.000000       9503.350368
# 6     7              1           360.000000       9503.350368
# 7     8              1           305.000000       9503.350368
# Total Power Produced: 8429.70 MW
# Total Fuel Cost: Rp 1575118.163901606
# Total Emissions (Tons):  9503.350368420335
# Computation Time: 1.058908224105835 seconds
# ------------------------------------------------
#
# Load Counter: 9
# Output for Power Demand 9837.60 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          3817.068730      10734.116771
# 1     2              1          1839.940065      10734.116771
# 2     3              1           645.124837      10734.116771
# 3     4              1           343.225847      10734.116771
# 4     5              1          1400.367174      10734.116771
# 5     6              1          1126.873829      10734.116771
# 6     7              1           360.000000      10734.116771
# 7     8              1           305.000000      10734.116771
# Total Power Produced: 9837.60 MW
# Total Fuel Cost: Rp 1749328.4943004989
# Total Emissions (Tons):  10734.116770705863
# Computation Time: 1.0535190105438232 seconds
# ------------------------------------------------
#
# Load Counter: 10
# Output for Power Demand 12063.50 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4081.666638      12815.617998
# 1     2              1          2215.747036      12815.617998
# 2     3              1           903.627165      12815.617998
# 3     4              1           607.829184      12815.617998
# 4     5              1          2198.059195      12815.617998
# 5     6              1          1391.571126      12815.617998
# 6     7              1           360.000000      12815.617998
# 7     8              1           305.000000      12815.617998
# Total Power Produced: 12063.50 MW
# Total Fuel Cost: Rp 2095062.131153211
# Total Emissions (Tons):  12815.617997909852
# Computation Time: 0.9740800857543945 seconds
# ------------------------------------------------
#
# Load Counter: 11
# Output for Power Demand 13486.70 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4090.544509      15928.850351
# 1     2              1          2142.941489      15928.850351
# 2     3              1           880.244632      15928.850351
# 3     4              1           590.547662      15928.850351
# 4     5              1          2274.848611      15928.850351
# 5     6              1          2842.573558      15928.850351
# 6     7              1           360.000000      15928.850351
# 7     8              1           305.000000      15928.850351
# Total Power Produced: 13486.70 MW
# Total Fuel Cost: Rp 2383022.2989608236
# Total Emissions (Tons):  15928.85035058534
# Computation Time: 0.9839727878570557 seconds
# ------------------------------------------------
#
# Load Counter: 12
# Output for Power Demand 14398.20 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4094.345999      18087.282508
# 1     2              1          2160.642191      18087.282508
# 2     3              1           877.932095      18087.282508
# 3     4              1           594.336135      18087.282508
# 4     5              1          2278.625929      18087.282508
# 5     6              1          3727.318249      18087.282508
# 6     7              1           360.000000      18087.282508
# 7     8              1           305.000000      18087.282508
# Total Power Produced: 14398.20 MW
# Total Fuel Cost: Rp 2608628.0802951753
# Total Emissions (Tons):  18087.282508341003
# Computation Time: 0.8887150287628174 seconds
# ------------------------------------------------
#
# Load Counter: 13
# Output for Power Demand 15037.90 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4086.912503      19835.953989
# 1     2              1          2180.969786      19835.953989
# 2     3              1           876.599705      19835.953989
# 3     4              1           586.902735      19835.953989
# 4     5              1          2224.180388      19835.953989
# 5     6              1          4417.335525      19835.953989
# 6     7              1           360.000000      19835.953989
# 7     8              1           305.000000      19835.953989
# Total Power Produced: 15037.90 MW
# Total Fuel Cost: Rp 2793923.8413036456
# Total Emissions (Tons):  19835.95398895893
# Computation Time: 0.9602599143981934 seconds
# ------------------------------------------------
#
# Load Counter: 14
# Output for Power Demand 15493.80 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4119.947393      20444.840077
# 1     2              1          2170.797594      20444.840077
# 2     3              1           941.907056      20444.840077
# 3     4              1           641.139379      20444.840077
# 4     5              1          2346.093164      20444.840077
# 5     6              1          4109.477631      20444.840077
# 6     7              1           807.910045      20444.840077
# 7     8              1           356.527738      20444.840077
# Total Power Produced: 15493.80 MW
# Total Fuel Cost: Rp 2833341.8391610915
# Total Emissions (Tons):  20444.840076603898
# Computation Time: 0.9054305553436279 seconds
# ------------------------------------------------
#
# Load Counter: 15
# Output for Power Demand 15837.40 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4146.502786      21247.015427
# 1     2              1          2226.698824      21247.015427
# 2     3              1           948.402136      21247.015427
# 3     4              1           641.533448      21247.015427
# 4     5              1          2299.460914      21247.015427
# 5     6              1          4660.478490      21247.015427
# 6     7              1           557.400278      21247.015427
# 7     8              1           356.923125      21247.015427
# Total Power Produced: 15837.40 MW
# Total Fuel Cost: Rp 2953921.9941381533
# Total Emissions (Tons):  21247.01542749653
# Computation Time: 0.9482600688934326 seconds
# ------------------------------------------------
#
# Load Counter: 16
# Output for Power Demand 16048.50 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4173.885732      21121.547938
# 1     2              1          2280.289773      21121.547938
# 2     3              1          1001.946338      21121.547938
# 3     4              1           685.138258      21121.547938
# 4     5              1          2353.017045      21121.547938
# 5     6              1          4236.855429      21121.547938
# 6     7              1           867.320076      21121.547938
# 7     8              1           450.047348      21121.547938
# Total Power Produced: 16048.50 MW
# Total Fuel Cost: Rp 2965680.0677612266
# Total Emissions (Tons):  21121.547938356096
# Computation Time: 0.8704030513763428 seconds
# ------------------------------------------------
#
# Load Counter: 17
# Output for Power Demand 16479.60 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4147.640657      22369.614478
# 1     2              1          2294.085101      22369.614478
# 2     3              1          1007.963889      22369.614478
# 3     4              1           690.024495      22369.614478
# 4     5              1          2368.610354      22369.614478
# 5     6              1          4677.256818      22369.614478
# 6     7              1           883.600253      22369.614478
# 7     8              1           410.418434      22369.614478
# Total Power Produced: 16479.60 MW
# Total Fuel Cost: Rp 3085476.5488067903
# Total Emissions (Tons):  22369.61447783625
# Computation Time: 0.5559189319610596 seconds
# ------------------------------------------------
#
# Load Counter: 18
# Output for Power Demand 16981.20 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4173.970914      22817.659411
# 1     2              1          2308.000000      22817.659411
# 2     3              1           989.829500      22817.659411
# 3     4              1           685.223439      22817.659411
# 4     5              1          2353.102227      22817.659411
# 5     6              1          4567.304248      22817.659411
# 6     7              1           900.000000      22817.659411
# 7     8              1          1003.768894      22817.659411
# Total Power Produced: 16981.20 MW
# Total Fuel Cost: Rp 3298854.2962947697
# Total Emissions (Tons):  22817.659411331224
# Computation Time: 0.5776388645172119 seconds
# ------------------------------------------------
#
# Load Counter: 19
# Output for Power Demand 17536.90 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4200.000000      23578.707299
# 1     2              1          2308.000000      23578.707299
# 2     3              1           971.419245      23578.707299
# 3     4              1           700.000000      23578.707299
# 4     5              1          2400.000000      23578.707299
# 5     6              1          4640.611164      23578.707299
# 6     7              1           878.207124      23578.707299
# 7     8              1          1438.661669      23578.707299
# Total Power Produced: 17536.90 MW
# Total Fuel Cost: Rp 3495648.895413042
# Total Emissions (Tons):  23578.70729904662
# Computation Time: 0.6068191528320312 seconds
# ------------------------------------------------
#
# Load Counter: 20
# Output for Power Demand 17822.40 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4200.000000      24002.728721
# 1     2              1          2308.000000      24002.728721
# 2     3              1          1008.000000      24002.728721
# 3     4              1           700.000000      24002.728721
# 4     5              1          2400.000000      24002.728721
# 5     6              1          4696.399058      24002.728721
# 6     7              1           900.000000      24002.728721
# 7     8              1          1610.000000      24002.728721
# Total Power Produced: 17822.40 MW
# Total Fuel Cost: Rp 3583462.183653837
# Total Emissions (Tons):  24002.728720636907
# Computation Time: 0.8492541313171387 seconds
# ------------------------------------------------
#
# Load Counter: 21
# Output for Power Demand 17489.30 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4200.000000      23513.833766
# 1     2              1          2266.378226      23513.833766
# 2     3              1           971.408529      23513.833766
# 3     4              1           690.075195      23513.833766
# 4     5              1          2352.984286      23513.833766
# 5     6              1          4603.893377      23513.833766
# 6     7              1           900.000000      23513.833766
# 7     8              1          1504.560044      23513.833766
# Total Power Produced: 17489.30 MW
# Total Fuel Cost: Rp 3489511.966266077
# Total Emissions (Tons):  23513.83376607526
# Computation Time: 0.6048226356506348 seconds
# ------------------------------------------------
#
# Load Counter: 22
# Output for Power Demand 16732.80 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4200.000000      22682.685876
# 1     2              1          2308.000000      22682.685876
# 2     3              1          1008.000000      22682.685876
# 3     4              1           690.064406      22682.685876
# 4     5              1          2400.000000      22682.685876
# 5     6              1          4714.000000      22682.685876
# 6     7              1           883.640163      22682.685876
# 7     8              1           529.094709      22682.685876
# Total Power Produced: 16732.80 MW
# Total Fuel Cost: Rp 3155351.309338886
# Total Emissions (Tons):  22682.685876490214
# Computation Time: 0.5132627487182617 seconds
# ------------------------------------------------
#
# Load Counter: 23
# Output for Power Demand 13892.40 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          4065.835061       17011.14367
# 1     2              1          2172.172927       17011.14367
# 2     3              1           875.592895       17011.14367
# 3     4              1           537.330269       17011.14367
# 4     5              1          2291.968237       17011.14367
# 5     6              1          3284.501119       17011.14367
# 6     7              1           360.000000       17011.14367
# 7     8              1           305.000000       17011.14367
# Total Power Produced: 13892.40 MW
# Total Fuel Cost: Rp 2503773.55872639
# Total Emissions (Tons):  17011.14366987431
# Computation Time: 0.8939821720123291 seconds
# ------------------------------------------------
#
# Load Counter: 24
# Output for Power Demand 10263.50 MW
#    Unit  On/Off Status  Power Produced (MW)  Emissions (Tons)
# 0     1              1          3717.349230      11530.230501
# 1     2              1          1955.932348      11530.230501
# 2     3              1           656.181549      11530.230501
# 3     4              1           313.393671      11530.230501
# 4     5              1          1875.643868      11530.230501
# 5     6              1          1080.000000      11530.230501
# 6     7              1           360.000000      11530.230501
# 7     8              1           305.000000      11530.230501
# Total Power Produced: 10263.50 MW
# Total Fuel Cost: Rp 1869198.9886355423
# Total Emissions (Tons):  11530.230501431031
# Computation Time: 1.0724029541015625 seconds
# ------------------------------------------------
#
# All results saved to 'GRASP-BLS (EED).xlsx'
